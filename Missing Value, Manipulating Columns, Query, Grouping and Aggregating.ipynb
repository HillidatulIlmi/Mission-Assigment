# %% [markdown]
# # PERKENALAN

# %% [markdown]
# - Nama : Hillidatul Ilmi
# - Batch : 12

# %% [markdown]
# **Graded Challenge 1**
#
# Dataset ini mencakup 721 Pokemon, termasuk nomor, nama, tipe pertama dan kedua, dan statistik dasar: HP, Serangan, Pertahanan, Serangan Khusus, Pertahanan Khusus, dan Kecepatan.
# Fitur dari data ini adalah:
# - #: ID untuk setiap pokemon
# - Name: Nama setiap pokemon
# - Tipe 1: Setiap pokemon memiliki tipe, ini menentukan kelemahan/ketahanan terhadap serangan
# - Tipe 2: Beberapa pokemon bertipe ganda dan memiliki 2
# - Total: jumlah semua statistik yang muncul setelah ini, panduan umum tentang seberapa kuat pokemon
# - HP: poin hit, atau kesehatan, menentukan berapa banyak kerusakan yang dapat ditahan oleh pokemon sebelum pingsan
# - Attack: pengubah dasar untuk serangan normal (mis. Scratch, Punch)
# - Pertahanan: resistensi kerusakan dasar terhadap serangan normal
# - SP Atk: serangan khusus, pengubah dasar untuk serangan khusus (misalnya ledakan api, balok gelembung)
# - SP Def: ketahanan kerusakan dasar terhadap serangan khusus
# - Kecepatan: menentukan pokemon mana yang menyerang lebih dulu setiap putaran

# %% [markdown]
# # Data Loading

# %%
# Berisi semua library
# Library yang digunakan adalah Numpy dan Pandas
import pandas as pd
import numpy as np

# %%
# Proses data loading atau memangil data untuk di analisis
d = pd.read_csv('Pokemon.csv')
d
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# Data yang di gunakan pada analisis Graded Challenge adalah permainan pokemon, yang terdiri dari 13 columns. 13 kolom nya berupa Id setiap pokemon, nama karakter pokemon yang dimainkan, tipe 1 sebagai kelemahan/kekuatan pokemon terhadap serangan, tipe 2 sebagai karakter pokemon bertipe ganda, Total dari kemunculan statistik mengenai kekuatan pokemon, HP berupa poin hit/kesehatan/menentukan berapa banyak kerusakan yang dapat ditahan oleh pokemon sebelum pingsan, Attack dengan pengubah dasar untuk serangan normal, Pertahanan dari resistensi kerusakan dasar terhadap serangan normal, SP Atk melihat mengenai serangan khusus/pengubah dasar untuk serangan khusus, SP Def untuk ketahanan kerusakan dasar terhadap serangan khusus dan Kecepatan dari pokemon mana yang menyerang lebih dulu setiap putaran . Sedangkan baris yang tersedia sebanyak 800 baris.

# %% [markdown]
# # Missing Value

# %% [markdown]
# Proses penyiapan data berupa data cleaning sebelum dilakukan explorasi data. Data cleaning di lakukan untuk menhindari data yang tidak baik untuk di analisis atau menghindari terjadi nya error. Missing valuee terjadi karena dua hal yaitu kesalahan manusia atau secara manual emang mengandung missing value.

# %% [markdown]
# 1. Standard Missing Value

# %%
missing_value = ["n/a","na","__"]

# %%
dc = pd.read_csv('Pokemon.csv', na_values = missing_value) #peroses cleaning missing value
dc
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# d.info memberikan informasi berupa dataset
# RangeIndex :> menampilkan jumlah entri data
# Akan menampilkan informasi yang ada di setiap kolom
# Non-Null Count :> Keberadaan missing value yang ada di setiap kolom nya, 
#                   jika jumlah non-null sama dengan entri data berarti keberadaan setdata hampir lengkap
#                   jika jumlah non-null kurang dari entri data bearti terdapat missing value dalam kolom dataset
# Dtype : Menampilkan type data setiap kolomnya (misal : hp type datanya int/name type datanya object-> gabungan str dan numerik)
# tpye data object lebih baik di ubah agar tidak memakan banyak memori dan bisa di ubah ke pandas categorical
# Missing value juga lebih baik di bersihkan atau di benerin
dc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# Untuk memastikan, akan dilakukan pengecekan missing value setiap kolom.

# %%
dc['Name'].isnull() #Tidak ada missing value
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Name, Length: 800, dtype: bool

# %%
dc['Legendary'].isnull() #Tidak ada missing value
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Legendary, Length: 800, dtype: bool

# %%
dc['Type 2'] #Melihat isi yang ada di dalam kolom Type 2
dc['Type 2'].isnull() # Ada Missing Value
# Jika di jalankan kolom Name dan Legendary akan tidak ada missing value
#Melihat apakah kolom Type 2 mengandung missing value. Jika boolean nya false berarti tidak mengandung missing value, 
# dan jika  True maka mengandung missing value.
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 2, Length: 800, dtype: bool

# %% [markdown]
# hasil analisa standard missing value
# - Berdasarkan proses .info yang digunakan untuk melihat spesifikasi masing-masing dataset kolom missing value, maka informasi dataset diperoleh bahwa kolom type 2 mengandung missing value sebesar 414 non-nul.
# - Berdasarkan proses .isnull, Kolom Name dan legendry tidak ada nilai yang missing karena boolean nya False semua sedangkan kolom type 2 terdapat boolean berupa True yang berarti mengndung missing value.

# %% [markdown]
# 2. Non-standard Missing Value

# %% [markdown]
# Untuk memastikan, akan dilakukan pengecekan missing value setiap kolom.

# %%
dc['Total'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Total, Length: 800, dtype: bool

# %%
dc['HP'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: HP, Length: 800, dtype: bool

# %%
dc['Attack'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Attack, Length: 800, dtype: bool

# %%
dc['Defense'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Defense, Length: 800, dtype: bool

# %%
dc['Sp. Atk'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Sp. Atk, Length: 800, dtype: bool

# %%
dc['Sp. Def'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Sp. Def, Length: 800, dtype: bool

# %%
dc['Speed'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Speed, Length: 800, dtype: bool

# %%
dc['Generation'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Generation, Length: 800, dtype: bool

# %% [markdown]
# hasil analisa Non-standard missing value
# - Berdasarkan proses .info yang digunakan untuk melihat spesifikasi masing-masing dataset kolom non-standar memiliki nilai non-null sama dengan entri data sebesar 800.
# - Berdasarkan proses .isnull, Kolom Total, HP, Attack, Defense, Sp.Atk, Sp.Def, Speed dan Generation tidak ada nilai yang missing karena boolean nya False semua.

# %% [markdown]
# # Manipulating Columns

# %%
# mencopy data, agar data asli masih tersedia
mp = dc.copy()
mp
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# Berdasarkan step sebelumnya yaitu pengecekan Missing value, di temukan kolom 2 mengandung missing value. Maka akan dilakukan penghapusan/menghilangkan kolom type 2, agar tidak menganggu analisa seterusnya. Untuk menghilangkan kolom Type 2, akan di akukan drop columns.

# %%
# drop column
# Menghapus kolom type 2, agar data set semuanya bersih atau tidak boleh ada missing value
mp.drop(labels=['Type 2'], axis=1, inplace=True)
mp
# Out:
#        #                   Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur    Grass    318  45      49       49       65
# 1      2                Ivysaur    Grass    405  60      62       63       80
# 2      3               Venusaur    Grass    525  80      82       83      100
# 3      3  VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4      4             Charmander     Fire    309  39      52       43       60
# ..   ...                    ...      ...    ...  ..     ...      ...      ...
# 795  719                Diancie     Rock    600  50     100      150      100
# 796  719    DiancieMega Diancie     Rock    700  50     160      110      160
# 797  720    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798  720     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799  721              Volcanion     Fire    600  80     110      120      130
#
# ...

# %% [markdown]
# # Explorasi Data Pokemon

# %% [markdown]
# 1. Function pada data set

# %%
mp # data yang sudah baik
# Out:
#        #                   Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0      1              Bulbasaur    Grass    318  45      49       49       65
# 1      2                Ivysaur    Grass    405  60      62       63       80
# 2      3               Venusaur    Grass    525  80      82       83      100
# 3      3  VenusaurMega Venusaur    Grass    625  80     100      123      122
# 4      4             Charmander     Fire    309  39      52       43       60
# ..   ...                    ...      ...    ...  ..     ...      ...      ...
# 795  719                Diancie     Rock    600  50     100      150      100
# 796  719    DiancieMega Diancie     Rock    700  50     160      110      160
# 797  720    HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798  720     HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799  721              Volcanion     Fire    600  80     110      120      130
#
# ...

# %%
mp.head() #Menampilkan 5 data teratas. Bisa masukkan (10) jika ingin melihat sampai 10
# Out:
#    #                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass    318  45      49       49       65
# 1  2                Ivysaur  Grass    405  60      62       63       80
# 2  3               Venusaur  Grass    525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 4  4             Charmander   Fire    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Misakan kolom ke samping tidak terlihat karena jumlahnya kolom yang banyak, terus kita mau melihat semuanya 
# memakai sintax di bawah ini dengan (None) berarti tidak ada batas alias terlihat semuanya
# d.set_option("dispay.max.columns", 5) :> syntax ini menampilkan 5 kolom saja
pd.set_option("display.max.columns", None)

# %%
# Menampilkan data yang paling bawah dalam dataset yang kita miliki
# d.tail (3) :> syntax ini menampilkan 3 data paling terbawah yang ada di dataset
mp.tail()
# Out:
#        #                 Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock    600  50     100      150      100
# 796  719  DiancieMega Diancie     Rock    700  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic    600  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic    680  80     160       60      170
# 799  721            Volcanion     Fire    600  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
# Menampilkan data secara acak
mp.sample() # Hanya menampilkan satu data saja, tapi jika ingin 5 data acak bisa d.sample (5)
# Out:
#        #      Name   Type 1  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 622  561  Sigilyph  Psychic    490  72      58       80      103       80
#
#      Speed  Generation  Legendary
# 622     97           5      False

# %%
mp.shape # Atribut dari jumlah baris dan jumlah kolom
# kolom awal nya 13, tetapi setelah di lakukan penghiangan menjadi 12 kolom.
# Out:
# (800, 12)

# %% [markdown]
# 2. Data Overview

# %%
# d.info memberikan informasi berupa dataset
mp.info() #Data yang sudah bersih
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 69.7+ KB

# %%
# describe di gunakan untuk melihat informasi dasar statistika deskriptif dari masing-masing kolom numerik
# kolom yang sifatnya bukan numerik tidak akan tertampil
mp.describe ().T
# Out:
#             count       mean         std    min     25%    50%     75%    max
# #           800.0  362.81375  208.343798    1.0  184.75  364.5  539.25  721.0
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.00  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.00    6.0

# %% [markdown]
# Deskriptif Data :
#
# 1. Id_Name : Dari deskriptif ini kita mengetahui bahwa kolom ID untuk setiap pokemon memiliki count entri data sebesar 800.0. Rata-rata pemain yang menggunakan ID untuk setiap pokemon sebesar 362.81375 dengan nilai tengah(Q2) sebesar 364.5, nilai rata-rata dan nilai tengah saling berdekatan, hal ini menandakan bahwa nilai Id_name berada dalam distribusi normal. Penggunaan ID untuk setiap pokemon paling sedikit/terendah adalah 1 dan paling banyak/tertinggi adalah 721.0. ID untuk setiap pokemon memiliki nilai Q1 sebesar 184.75 dan nilai Q3 sebesar 539.25. Nilai standar deviasi ID untuk setiap pokemon sebesar 208.343798, yang berarti sebaran sampel data sampel dari rata-rata nilai dari sampel itu sendiri.
#
# 2. Total : Dari deskriptif ini kita mengetahui bahwa panduan umum tentang seberapa kuat pokemon memiliki count entri data sebesar 800.0. Rata-rata panduan umum tentang seberapa kuat pokemon sebesar 435.10250 dengan nilai tengah (Q2) sebesar 450, nilai rata-rata dan nilai tengah saling berjauhan, hal ini menandakan bahwa nilai Total berada jauh dari kisaran distribusi normal. Panduan umum tentang seberapa kuat pokemon paling sedikit/terendah adalah 180 dan paling banyak/tertinggi adalah 780. Panduan umum tentang seberapa kuat pokemon memiliki nilai Q1 sebesar 330 dan nilai Q3 sebesar 515. Nilai standar deviasi Total untuk setiap pokemon sebesar 119.96304, yang berarti sebaran sampel data sampel dari rata-rata nilai dari sampel itu sendiri.
#
# 3. HP : Dari deskriptif ini kita mengetahui bahwa  kerusakan yang dapat ditahan oleh pokemon sebelum pingsan memiliki count entri data sebesar 800.0. Rata-rata kerusakan yang dapat ditahan oleh pokemon sebelum pingsan sebesar 69.2534669 dengan nilai tengah (Q2) sebesar 65, nilai rata-rata dan nilai tengah saling berdekatann, hal ini menandakan bahwa nilai Total berada dari kisaran distribusi normal.  Kerusakan yang dapat ditahan oleh pokemon sebelum pingsan paling sedikit/terendah adalah 1 dan paling banyak/tertinggi adalah 255.  Kerusakan yang dapat ditahan oleh pokemon sebelum pingsan memiliki nilai Q1 sebesar 50 dan nilai Q3 sebesar 80. Nilai standar deviasi HP sebesar 25.534669, yang berarti sebaran sampel data sampel dari rata-rata nilai dari sampel itu sendiri.
#
# 4. Attack : Dari deskriptif ini kita mengetahui bahwa pengubah dasar untuk serangan normal memiliki count entri data sebesar 800.0. Rata-rata pengubah dasar untuk serangan normal sebesar 79.00125 dengan nilai tengah (Q2) sebesar 75, nilai rata-rata dan nilai tengah saling berdekatann, hal ini menandakan bahwa nilai Total berada dari kisaran distribusi normal. Pengubah dasar untuk serangan normal paling sedikit/terendah adalah 5 dan paling banyak/tertinggi adalah 190.  Pengubah dasar untuk serangan normal memiliki nilai Q1 sebesar 55 dan nilai Q3 sebesar 100. Nilai standar deviasi Attack sebesar 32.457366, yang berarti sebaran sampel data sampel dari rata-rata nilai dari sampel itu sendiri.
#
# 5. Defense : Dari deskriptif ini kita mengetahui bahwa resistensi kerusakan dasar terhadap serangan normal memiliki count entri data sebesar 800.0. Rata-rata resistensi kerusakan dasar terhadap serangan normal sebesar 73.8425 dengan nilai tengah (Q2) sebesar 70, nilai rata-rata dan nilai tengah saling berdekatann, hal ini menandakan bahwa nilai Total berada dari kisaran distribusi normal. Resistensi kerusakan dasar terhadap serangan normal paling sedikit/terendah adalah 5 dan paling banyak/tertinggi adalah 230. Resistensi kerusakan dasar terhadap serangan normal memiliki nilai Q1 sebesar 50 dan nilai Q3 sebesar 90. Nilai standar deviasi defense sebesar 31.183501, yang berarti sebaran sampel data sampel dari rata-rata nilai dari sampel itu sendiri.
#
# 6. Sp Atk : Dari deskriptif ini kita mengetahui bahwa pengubah dasar untuk serangan khusus memiliki count entri data sebesar 800.0. Rata-rata pengubah dasar untuk serangan khusus sebesar 72.82 dengan nilai tengah (Q2) sebesar 65, nilai rata-rata dan nilai tengah saling berjahuan, hal ini menandakan bahwa nilai Total jauh berada dari kisaran distribusi normal. Pengubah dasar untuk serangan khusus paling sedikit/terendah adalah 10 dan paling banyak/tertinggi adalah 194. Pengubah dasar untuk serangan khusus memiliki nilai Q1 sebesar 49.75 dan nilai Q3 sebesar 95. Nilai standar deviasi Sp Atk sebesar 32.722294, yang berarti sebaran sampel data sampel dari rata-rata nilai dari sampel itu sendiri.
#
# 6. Sp Def : Dari deskriptif ini kita mengetahui bahwa ketahanan kerusakan dasar terhadap serangan khusus memiliki count entri data sebesar 800.0. Rata-rata pketahanan kerusakan dasar terhadap serangan khusus sebesar 71.9025 dengan nilai tengah (Q2) sebesar 70, nilai rata-rata dan nilai tengah saling berdekatan, hal ini menandakan bahwa nilai Total berada dari kisaran distribusi normal. Ketahanan kerusakan dasar terhadap serangan khusus paling sedikit/terendah adalah 20 dan paling banyak/tertinggi adalah 230. Ketahanan kerusakan dasar terhadap serangan khusus memiliki nilai Q1 sebesar 50 dan nilai Q3 sebesar 90. Nilai standar deviasi Sp Def sebesar 27.828916, yang berarti sebaran sampel data sampel dari rata-rata nilai dari sampel itu sendiri.
#
# 7. Speed : Dari deskriptif ini kita mengetahui pokemon yang menyerang lebih dulu setiap putaran memiliki count entri data sebesar 800.0. Rata-rata  pokemon yang menyerang lebih dulu setiap putaran sebesar 68.2775 dengan nilai tengah (Q2) sebesar 65, nilai rata-rata dan nilai tengah saling berdekatan, hal ini menandakan bahwa nilai Total berada dari kisaran distribusi normal. Pokemon yang menyerang lebih dulu setiap putaran paling sedikit/terendah adalah 5 dan paling banyak/tertinggi adalah 180. Pokemon yang menyerang lebih dulu setiap putaran memiliki nilai Q1 sebesar 45 dan nilai Q3 sebesar 90. Nilai standar deviasi speed sebesar 29.060474, yang berarti sebaran sampel data sampel dari rata-rata nilai dari sampel itu sendiri.
#
# 8. Generation : Dari deskriptif ini kita mengetahui Generation memiliki count entri data sebesar 800.0. Rata-rata Generation sebesar 3.32375 dengan nilai tengah (Q2) sebesar 3, nilai rata-rata dan nilai tengah saling berdekatan, hal ini menandakan bahwa nilai Total berada dari kisaran distribusi normal. Generation setiap putaran paling sedikit/terendah adalah 2 dan paling banyak/tertinggi adalah 5. Generation memiliki nilai Q1 sebesar 2 dan nilai Q3 sebesar 5. Nilai standar deviasi Generation sebesar 1.66129, yang berarti sebaran sampel data sampel dari rata-rata nilai dari sampel itu sendiri.

# %% [markdown]
# 3. Data Exploratiom

# %%
# Mislkan ingin mengetahui unique yang terkandung dalam kolom name
mp['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
# Ingin mengetahui kemunculan frekuensi pada masing-masing unique
mp['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %% [markdown]
# Nilai frekuensi tertinggi pada kolom Type 1 berada pada baris Water dengan besaran frekunsi adalah 112. Nilai frekuensi terkecil pada kolom Type 1 berada pada baris Flying dengan besaran frekunsi adalah 4.

# %%
mp['Legendary'].value_counts()
# Out:
# False    735
# True      65
# Name: Legendary, dtype: int64

# %% [markdown]
# Nilai frekuensi tertinggi pada kolom Legendary berada pada baris False dengan besaran frekunsi adalah 735. Nilai frekuensi terkecil pada kolom legendary berada pada baris True dengan besaran frekunsi adalah 65.

# %%
# Dokumentasikan perbedaan kolom type 1 dan legendary
mp[['Type 1', 'Legendary']] # Multipel Value
# Out:
#       Type 1  Legendary
# 0      Grass      False
# 1      Grass      False
# 2      Grass      False
# 3      Grass      False
# 4       Fire      False
# ..       ...        ...
# 795     Rock       True
# 796     Rock       True
# 797  Psychic       True
# 798  Psychic       True
# 799     Fire       True
#
# [800 rows x 2 columns]

# %%
# kita ingin mencari tau mengenai perbedaan frekuensi name dan type 1
# menggunakan loc dan iloc
# misalkan kita ingin melihat normal di type 1
mp.loc[d['Type 1']=='Water',:] # Tanda : untuk semua kolom
# hasil balikan dari dataframe, yang di mana semua data type 1 itu adalah water. sesuai yang kita inginkan
# Out:
#        #                     Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 9      7                 Squirtle  Water    314  44      48       65       50
# 10     8                Wartortle  Water    405  59      63       80       65
# 11     9                Blastoise  Water    530  79      83      100       85
# 12     9  BlastoiseMega Blastoise  Water    630  79     103      120      135
# 59    54                  Psyduck  Water    320  50      52       48       65
# ..   ...                      ...    ...    ...  ..     ...      ...      ...
# 724  656                  Froakie  Water    314  41      56       40       62
# 725  657                Frogadier  Water    405  54      63       52       83
# 726  658                 Greninja  Water    530  72      95       67      103
# 762  692                Clauncher  Water    330  50      53       62       58
# 763  693                Clawitzer  Water    500  71      73       88      120
#
# ...

# %% [markdown]
# Berdasararkan .loc dataframe type 1 frekunsi Water yang terlihat, bahwa kolom legendary memiliki 2 tipe yaitu True dan False.

# %%
mp.loc[mp['Type 1']=='Water','Legendary'].value_counts()
# Out:
# False    108
# True       4
# Name: Legendary, dtype: int64

# %%
108 + 4
# maka hasilnya sesuai dengan baris water pada kolom type 1
# Out:
# 112

# %%
# .loc with multiple columns
# Memasukkan multiple kolom 
# menampilkan data water pada kolom type 1 yang di sesuaikan kolom Name, Total, HP, Attack, Defense dan Speed. 
mp.loc[mp['Type 1']=='Water', 
['Name','Total','HP','Attack','Defense','Speed']] #memakai list untuk melihat data multiple
# Out:
#                         Name  Total  HP  Attack  Defense  Speed
# 9                   Squirtle    314  44      48       65     43
# 10                 Wartortle    405  59      63       80     58
# 11                 Blastoise    530  79      83      100     78
# 12   BlastoiseMega Blastoise    630  79     103      120     78
# 59                   Psyduck    320  50      52       48     55
# ..                       ...    ...  ..     ...      ...    ...
# 724                  Froakie    314  41      56       40     71
# 725                Frogadier    405  54      63       52     97
# 726                 Greninja    530  72      95       67    122
# 762                Clauncher    330  50      53       62     44
# 763                Clawitzer    500  71      73       88     59
#
# [112 rows x 6 columns]

# %%
# Multiple Condition, di bungkus dengan tuples
mp.loc[(mp['Type 1']=='Water')&(mp['Legendary']=='False'), :].head()
# Out:
# Empty DataFrame
# Columns: [#, Name, Type 1, Total, HP, Attack, Defense, Sp. Atk, Sp. Def, Speed, Generation, Legendary]
# Index: []

# %%
 #melihat rata-rata nilai Attack yang kolom type 1 : water dan Legendary : False pada kolom Generation
 mp.loc[(mp['Type 1']=='Water')&(mp['Legendary']=='False'), 'Generation'].mean()
# Out:
# nan

# %% [markdown]
# # Query

# %% [markdown]
# - Mencari spesifikasi pada datasetnya

# %%
mp.head()
# Out:
#    #                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass    318  45      49       49       65
# 1  2                Ivysaur  Grass    405  60      62       63       80
# 2  3               Venusaur  Grass    525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 4  4             Charmander   Fire    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# pada dataframe akan di lakukan filtering
# melihat datafram dengan 1 kondisi
mp[
    mp['Total'] > 500
]
# Out:
#        #                       Name   Type 1  Total  HP  Attack  Defense  \
# 2      3                   Venusaur    Grass    525  80      82       83
# 3      3      VenusaurMega Venusaur    Grass    625  80     100      123
# 6      6                  Charizard     Fire    534  78      84       78
# 7      6  CharizardMega Charizard X     Fire    634  78     130      111
# 8      6  CharizardMega Charizard Y     Fire    634  78     104       78
# ..   ...                        ...      ...    ...  ..     ...      ...
# 795  719                    Diancie     Rock    600  50     100      150
# 796  719        DiancieMega Diancie     Rock    700  50     160      110
# 797  720        HoopaHoopa Confined  Psychic    600  80     110       60
# 798  720         HoopaHoopa Unbound  Psychic    680  80     160       60
# 799  721                  Volcanion     Fire    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Menampilkan filtering kolom Total yang memiliki baris atas 500

# %%
# Multiple dengan 4 kondisi
mp[
    (mp['Type 1']=='Water') &
    (mp['Total'] > 500) & 
    (mp['HP'] > 50) &
    (mp['Attack'] > 90)
]
# Out:
#        #                     Name Type 1  Total   HP  Attack  Defense  \
# 12     9  BlastoiseMega Blastoise  Water    630   79     103      120
# 67    62                Poliwrath  Water    510   90      95       95
# 140  130                 Gyarados  Water    540   95     125       79
# 141  130    GyaradosMega Gyarados  Water    640   95     155      109
# 174  160               Feraligatr  Water    530   85     105      100
# 249  230                  Kingdra  Water    540   75      95       95
# 282  260                 Swampert  Water    535  100     110       90
# 283  260    SwampertMega Swampert  Water    635  100     150      110
# 349  319    SharpedoMega Sharpedo  Water    560   70     140       70
# 421  382                   Kyogre  Water    670  100     100       90
# 422  382      KyogrePrimal Kyogre  Water    770  100     150       90
# 541  484                   Palkia  Water    680   90     120      100
# ...

# %%
# Multiple dengan 4 kondisi
# Menampilkan kolom yang hanya di lakukan filtering saja
mp[
    (mp['Type 1']=='Water') &
    (mp['Total'] > 500) & 
    (mp['HP'] > 50) &
    (mp['Attack'] > 90)
][['Type 1', 'Total', 'HP', 'Attack']]
# Out:
#     Type 1  Total   HP  Attack
# 12   Water    630   79     103
# 67   Water    510   90      95
# 140  Water    540   95     125
# 141  Water    640   95     155
# 174  Water    530   85     105
# 249  Water    540   75      95
# 282  Water    535  100     110
# 283  Water    635  100     150
# 349  Water    560   70     140
# 421  Water    670  100     100
# 422  Water    770  100     150
# 541  Water    680   90     120
# 548  Water    600  100     100
# 562  Water    528   95     100
# 597  Water    509  105      95
# 726  Water    530   72      95

# %% [markdown]
# Hasil filtering pada dataframe di atas menampilkan kolom type 1 dengan baris water, kolom Total dengan nilai barisnya > 500, kolom HP dengan nilai barisnya > 50 dan kolom Attack dengn nilai barisnya > 90. Berdasarkan filtering menghasilkan data frame dengan 16 baris dan 4 kolom.

# %%
# Multiple dengan 4 kondisi
# Menampilkan kolom yang hanya di lakukan filtering saja
mp[
    (mp['Type 1']=='Grass') & # memfilter kolom 1 dengan baris Grass
    (mp['Total'] >= 400) & # memfilter kolom total dengna baris nilai nya antara 400-700
    (mp['Total'] <= 700) & 
    (mp['HP'] % 2 !=0) & # memfiter kolom hp dengan baris berupa angka ganjil
    (mp['Attack'] > 90) #memfilter attack dengan baris di atas 90
][['Type 1', 'Total', 'HP', 'Attack']]
# Out:
#     Type 1  Total   HP  Attack
# 111  Grass    520   95      95
# 434  Grass    525   95     109
# 521  Grass    525   65     110
# 571  Grass    498   75      98
# 741  Grass    531  123     100

# %% [markdown]
# Hasil filtering pada dataframe di atas menampilkan kolom type 1 dengan baris Grass, kolom Total dengan nilai barisnya antara 400-700, kolom HP dengan barisnya bilangan ganjil dan kolom Attack dengan barisnya > 90. Berdasarkan filtering menghasilkan data frame dengan 16 baris dan 12 kolom.

# %%
# Cara lain dengan memakai .query 
mp.query("Total >= 500 & HP <= 70 & Attack % 2 !=0")[['Total', 'HP', 'Attack']]
# Out:
#      Total  HP  Attack
# 98     525  50      95
# 101    500  60      65
# 102    600  60      65
# 130    520  60      75
# 136    500  65     125
# 137    600  65     155
# 146    525  65      65
# 211    525  65      65
# 274    530  70      85
# 305    518  68      65
# 306    618  68      85
# 339    575  70      75
# 387    555  64     165
# 431    600  50      95
# 485    500  67      89
# 498    625  70     145
# 526    518  68     125
# 527    618  68     165
# 528    525  60      55
# 532    520  50      65
# 533    520  50      65
# 534    520  50      65
# 535    520  50      65
# 536    520  50      65
# 632    510  60     105
# 670    520  60      55
# 681    510  65     125

# %%
mp.query("Total >= 500 & HP <= 70 & Attack % 2 !=0")[['Total', 'HP', 'Attack']].shape
#shape di gunakan untuk melihat jumlah baris dan kolom
# Out:
# (27, 3)

# %%
# penulisan cara lain pada .query
mp.query("Total >= 500 & \
        HP <= 70 & \
         Attack % 2 !=0").shape
# Out:
# (27, 12)

# %% [markdown]
# Hasil filtering pada dataframe di atas menampilkan kolom Total dengan nilai barisnya antara >= 500, kolom HP dengan barisnya <= 70 dan kolom Attack dengan barisnya ganjil. Berdasarkan filtering dengan menggunakan perintah shape menghasilkan data frame dengan 27 baris dan 3 kolom.

# %% [markdown]
# # Grouping and Aggregating

# %%
mp.head()
# Out:
#    #                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass    318  45      49       49       65
# 1  2                Ivysaur  Grass    405  60      62       63       80
# 2  3               Venusaur  Grass    525  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 4  4             Charmander   Fire    309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
# Memakai kolom Type 1 sebagai grouping dan kolom Total sebagai aggregating secara rata-rata
mp.groupby(by='Type 1')[['Total']].mean()
# Out:
#                Total
# Type 1
# Bug       378.927536
# Dark      445.741935
# Dragon    550.531250
# Electric  443.409091
# Fairy     413.176471
# Fighting  416.444444
# Fire      458.076923
# Flying    485.000000
# Ghost     439.562500
# Grass     421.142857
# Ground    437.500000
# Ice       433.458333
# Normal    401.683673
# Poison    399.142857
# Psychic   475.947368
# Rock      453.750000
# Steel     487.703704
# Water     430.455357

# %%
mp.groupby(by='Type 1')[['Total']].mean().sort_values(by='Total', ascending=False).head()
# Akan menampilkan nilai rata-rata tertinggi
# Out:
#               Total
# Type 1
# Dragon   550.531250
# Steel    487.703704
# Flying   485.000000
# Psychic  475.947368
# Fire     458.076923

# %%
# elaborasi cara kerja
G = mp.groupby(by='Type 1')

# %%
# membagi dataframe secara keseluruhan menjadi bagian-bagian berdasarkan groupinng Grass
G.get_group('Grass').head()
# Out:
#      #                   Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur  Grass    318  45      49       49       65
# 1    2                Ivysaur  Grass    405  60      62       63       80
# 2    3               Venusaur  Grass    525  80      82       83      100
# 3    3  VenusaurMega Venusaur  Grass    625  80     100      123      122
# 48  43                 Oddish  Grass    320  45      50       55       75
#
#     Sp. Def  Speed  Generation  Legendary
# 0        65     45           1      False
# 1        80     60           1      False
# 2       100     80           1      False
# 3       120     80           1      False
# 48       65     30           1      False

# %%
# membagi dataframe secara keseluruhan menjadi bagian-bagian berdasarkan groupinng Water
G.get_group('Water').head()
# Out:
#      #                     Name Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 9    7                 Squirtle  Water    314  44      48       65       50
# 10   8                Wartortle  Water    405  59      63       80       65
# 11   9                Blastoise  Water    530  79      83      100       85
# 12   9  BlastoiseMega Blastoise  Water    630  79     103      120      135
# 59  54                  Psyduck  Water    320  50      52       48       65
#
#     Sp. Def  Speed  Generation  Legendary
# 9        64     43           1      False
# 10       80     58           1      False
# 11      105     78           1      False
# 12      115     78           1      False
# 59       50     55           1      False

# %%
# membagi dataframe secara keseluruhan menjadi bagian-bagian berdasarkan groupinng Water
G.get_group('Dragon').head()
# Out:
#        #                 Name  Type 1  Total  HP  Attack  Defense  Sp. Atk  \
# 159  147              Dratini  Dragon    300  41      64       45       50
# 160  148            Dragonair  Dragon    420  61      84       65       70
# 161  149            Dragonite  Dragon    600  91     134       95      100
# 365  334              Altaria  Dragon    490  75      70       90       70
# 366  334  AltariaMega Altaria  Dragon    590  75     110      110      110
#
#      Sp. Def  Speed  Generation  Legendary
# 159       50     50           1      False
# 160       70     70           1      False
# 161      100     80           1      False
# 365      105     80           3      False
# 366      105     80           3      False

# %%
G.get_group('Grass')['Total'].mean()
# Out:
# 421.14285714285717

# %%
G.get_group('Water')['Total'].mean()
# Out:
# 430.45535714285717

# %%
G.get_group('Dragon')['Total'].mean()
# Out:
# 550.53125

# %%
# Multiple dengan 4 kelompok
mp[
    (mp['Type 1']=='Water') &
    (mp['Total'] >= 400) & 
    (mp['Total'] <= 750) & 
    (mp['HP'] > 50) &
    (mp['Attack'] > 90)
].groupby(by=['Type 1', 'Legendary'])[['Total']].mean()
# Out:
#                     Total
# Type 1 Legendary
# Water  False      520.125
#        True       675.000

# %% [markdown]
# Water dengan legendary bertipe False memiliki rata-rata 520.125 dan water dengan legendary bertipe True memiliki rata-rata 675.000

# %% [markdown]
# # Pandas Visualization

# %%
mp['Type 1'].value_counts().head().plot()

# %% [markdown]
# Plot garis pada kolom Type 1 menunjukan frekunsi tertinggi adalah water, hingga frekunsi yang terendah adalah psychic.

# %%
mp['Legendary'].value_counts().head().plot(kind='bar')

# %% [markdown]
# Histogram pada kolom Legendary menunjukan frekunsi tertinggi adalah boolean False, hingga frekunsi yang terendah adalah boolean True.

# %%
mp['Type 1'].value_counts().head().plot(kind='bar')

# %% [markdown]
# Histogram pada kolom Type 1 menunjukan frekunsi tertinggi adalah water, hingga frekunsi yang terendah adalah psychic.

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Pada analisis data pokemon di tahap awal pemangilan data di temukan informasi missing value yang dapat menganggu analisis pengolahan data pokemon secara keseluruhan, oleh karena itu di tahap manipulation columns di lakukan pembersihan kolom yang mengandung missing value. Sehingga seluruh perintah analisis ekplorasi data, query, grouping dan aggregating serta visualisi data bisa di lakukan semua.
